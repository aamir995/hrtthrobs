# %%
# Course - Deep Learning (Esp in Images) | AI 
# 


# Framework - 
# - Google - TensorFlow 
# - FB     - PyTorch 

# Industry - TensorFlow 
# Academia - PyTorch 

# Keras - Wrapper!

# %%
# DS Vs ML Vs DL Vs AI 


# DS - Data Science 
# Generate insights .... 

# ML - Predict 
# use data to find patterns and predict
# tabluar 

# Non Tabular - Images, Video, Speech
# DL - 
# Mimics how a human learns ! 
########################1980######################
#
#
# Image Net - 1M images - 1000 cat 


# AI - Product Level 
#

# %%
####### LIFE CYCLE OF DEEP LEARNING ############
# Make a DL model to differntiate between Cats & Dogs images 
# INPUT - Images 
# OUTPUT - Text (Cat Vs Dog)

# ##### 
# Phase I = Training --- 
# [INPUT], [OUTPUT] ==> NEURAL NETWORK ==> C&D Model 
# Images, Labels    --> AI NETWORK     --> C&D Model 

# Phase II = Testing ---
# INPPUT ==> C&D Model --> [Pred OUTPUT]
# [IMAGES] == > C&D Model --> [Pred OUTPUT]
# -- Evaluation -- Comparing [Pred OUTPUT] Vs ORIGNAL OUTPUT 

# Either Model passes or fails ... 
# If Model fails --- go back to Phase I 
# but if model passes - move to phase III 

# Phase III = Inferecning/ Prduction 
# [INPUT] ==> C&D MOdel --> {OUTPUT}
# Image --> C&D MOodel --> Labels

# %%
# Training Phase - Images & their labels ... Labelled Data ... 
# 1.1 - Collect Data 
# 1.2 - Validate or label data 
# 1.3 - Make it ready for training 


# 2.1 Training 
# 2.2 Iteration 
# 2.3 Hyper parameters 
# 2.4 Evaluation . . . . 

# 3.1 Testing 
# 3.2 Testing should be different from Training data ... 
# 3.3 Re evaluate 

# 4. Inferencing
