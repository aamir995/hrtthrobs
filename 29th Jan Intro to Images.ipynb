# %%
# cv2 
# Install 
# ! pip install opencv-python 
# PIL 
# ! pip install pillow

# %%
# Check if lib is installed or not! 
! pip list | grep opencv
# Out:
# opencv-contrib-python         4.1.2.30
# opencv-python                 4.1.2.30

# %%
import PIL
import cv2

# %%
PIL.Image.open("download.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=194x259 at 0x7F7AF8AC9090>

# %%
import cv2

# %%
image = cv2.imread("download.jpeg")

# %%
image.shape # returns heigh, width, channel
# Out:
# (259, 194, 3)

# %%
# Channels are multi level array structure to store color values ( R, G, B)
# Pixel values (0 - 255)
image.max(), image.min()
# Out:
# (255, 0)

# %%
# 1/3/4 channel 
# Single channel images - (150, 150, 1) - GreyScale Images
# 4 channel  - (340, 230, 4) - 4th channel is transperancy

# Video - (fps(24), 345, 234, 3)

# %%
# Plot Images 
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
PIL.Image.open("download.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=194x259 at 0x7F7AF7723B50>

# %%
plt.imshow(image[:,:,::-1])

# %%
image2 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.subplot(1,2,1)
plt.imshow(image)

plt.subplot(1,2,2)
plt.imshow(image2)

# %%
# Resizing Vs Cropping! 

image2.shape # 260, 194, 3 
plt.imshow(image2[130:, 97:, 2], cmap="gray")

# %%
! wget https://www.gogoprint.sg/media/wysiwyg/RGB_1.png
# Out:
# --2022-01-29 15:36:27--  https://www.gogoprint.sg/media/wysiwyg/RGB_1.png
# Resolving www.gogoprint.sg (www.gogoprint.sg)... 104.26.12.213, 104.26.13.213, 172.67.68.1, ...
# Connecting to www.gogoprint.sg (www.gogoprint.sg)|104.26.12.213|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26586 (26K) [image/png]
# Saving to: ‘RGB_1.png’
#
# RGB_1.png           100%[===================>]  25.96K  --.-KB/s    in 0.002s
#
# 2022-01-29 15:36:28 (14.7 MB/s) - ‘RGB_1.png’ saved [26586/26586]

# %%
rgb = cv2.imread("RGB_1.png")
plt.imshow(rgb)

# %%
rgb2 = cv2.cvtColor(rgb, cv2.COLOR_BGR2RGB)
plt.imshow(rgb2)

# %%
plt.imshow(rgb2[:, :, 2], cmap="gray")

# %%
# Resizing 
image3 = cv2.resize(image2, (100, 100))
plt.subplot(1,2,1)
plt.imshow(image2)

plt.subplot(1,2,2)
plt.imshow(image3)

# %%
image3.shape
# Out:
# (100, 100, 3)

# %%
rgb3 = cv2.resize(rgb2, (100, 100)) # (image, new_dim)

# %%
plt.imshow(rgb3)

# %%
! wget https://love2dev.com/img/css_responsive-background-hero_hdpi-just-background-opacity-full-screen-2880x1800.jpg
# Out:
# --2022-01-29 15:55:32--  https://love2dev.com/img/css_responsive-background-hero_hdpi-just-background-opacity-full-screen-2880x1800.jpg
# Resolving love2dev.com (love2dev.com)... 65.9.78.23, 65.9.78.72, 65.9.78.43, ...
# Connecting to love2dev.com (love2dev.com)|65.9.78.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 689082 (673K) [image/jpeg]
# Saving to: ‘css_responsive-background-hero_hdpi-just-background-opacity-full-screen-2880x1800.jpg’
#
# css_responsive-back 100%[===================>] 672.93K  1.83MB/s    in 0.4s
#
# 2022-01-29 15:55:32 (1.83 MB/s) - ‘css_responsive-background-hero_hdpi-just-background-opacity-full-screen-2880x1800.jpg’ saved [689082/689082]

# %%
! wget https://cdn.pixabay.com/photo/2015/04/23/22/00/tree-736885__480.jpg
# Out:
# --2022-01-29 16:00:04--  https://cdn.pixabay.com/photo/2015/04/23/22/00/tree-736885__480.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.21.183, 104.18.20.183, 2606:4700::6812:15b7, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.21.183|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46606 (46K) [image/jpeg]
# Saving to: ‘tree-736885__480.jpg’
#
# tree-736885__480.jp 100%[===================>]  45.51K  --.-KB/s    in 0s
#
# 2022-01-29 16:00:04 (128 MB/s) - ‘tree-736885__480.jpg’ saved [46606/46606]

# %%
plt.imshow(cv2.cvtColor(cv2.imread("tree-736885__480.jpg"), cv2.COLOR_BGR2RGB))

# %%
# TensorFlow 
# Keras - Official API

# Install 
#! pip install tensorflow

! pip list | grep tensorflow
# Out:
# tensorflow                    2.7.0
# tensorflow-datasets           4.0.1
# tensorflow-estimator          2.7.0
# tensorflow-gcs-config         2.7.0
# tensorflow-hub                0.12.0
# tensorflow-io-gcs-filesystem  0.23.1
# tensorflow-metadata           1.6.0
# tensorflow-probability        0.15.0

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.7.0'

# %%
tf.keras
# Out:
# <module 'keras.api._v2.keras' from '/usr/local/lib/python3.7/dist-packages/keras/api/_v2/keras/__init__.py'>

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# ...
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_test.shape
# Out:
# (10000,)

# %%
import numpy as np
num = np.random.randint(0, 60000, 1)
num= num[0]
print(f"Random Number {num}")
#-------------------#
print(y_train[num])
plt.imshow(x_train[num, :, : ], cmap="gray")
plt.show()
# Out:
# Random Number 54244
# 9

# %%
import pandas as pd
a = pd.Series(y_train)
a.value_counts().plot.bar()

# %%
all_ones = np.where(y_train == 1)[0][:5]

# %%
plt.figure(figsize=(13, 10))
num = 0
all_index = np.random.choice(np.where(y_train == num)[0], 10)
for index, i in enumerate(all_index):
  plt.subplot(1,10,index+1)
  plt.imshow(x_train[i, :, : ], cmap="gray")

# %%
# print 10 images of 0 -9 in row
